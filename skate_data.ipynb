# %%
import numpy as np
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from sklearn.externals import joblib

# %%
X_train = joblib.load('X_train.pkl')

# %%
print(len(X_train))
# Out:
# 12

# %%
cap = cv2.VideoCapture('./non-ollie/My Movie 47.mp4')
data = []

while(cap.isOpened()):
    ret, frame = cap.read()
    
    gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
    
    gray_resized = cv2.resize(gray, (120,160))
    
    data.append(gray_resized)

    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-135-a80f57979fa2> in <module>()
#       6     ret, frame = cap.read()
#       7
# ----> 8     gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
#       9
#      10     gray_resized = cv2.resize(gray, (120,160))
#
# error: /Users/jenkins/miniconda/1/x64/conda-bld/work/opencv-3.1.0/modules/imgproc/src/color.cpp:7456: error: (-215) scn == 3 || scn == 4 in function ipp_cvtColor

# %%
print (len(data))
# Out:
# 44

# %%
X_train.append(data)

# %%
img = X_train[len(X_train)-1][0] 

img = cv2.resize(img, (100,100))
print(img.shape)
plt.imshow(img, cmap = 'gray')
plt.show()
# Out:
# (100, 100)

# %%
print(len(X_train))
# Out:
# 32

# %%
for i in X_train:
    print (len(i))
# Out:
# 66
# 95
# 50
# 54
# 47
# 44
# 30
# 55
# 29
# 82
# 64
# 62
# 58
# 55
# 55
# 50
# 52
# 57
# 55
# 41
# 56
# 40
# 43
# 43
# 43
# 38
# 44
# 40
# 44
# 44
# 42
# 44

# %%
y_train.append(0)

# %%
len(y_train)
# Out:
# 32

# %%
from sklearn.externals import joblib
joblib.dump(X_train, 'X_train.pkl')
# Out:
# ['X_train.pkl']

# %%
joblib.dump(y_train, 'y_train.pkl')
# Out:
# ['y_train.pkl']
